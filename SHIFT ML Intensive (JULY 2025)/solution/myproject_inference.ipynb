# %% [markdown]
# # Импорт и функции

# %%
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split

import gradio as gr

# %%
def columns_drop(train_full_info):
    
    mask_avg_dep = train_full_info.columns.str.startswith('avg_dep_avg_balance_fact_')
    mask_zp = train_full_info.columns.str.startswith('zp_')
    mask_agg = (train_full_info.columns.str.startswith(('max_', 'min_', 'avg_', 'sum_'))
                & ~train_full_info.columns.isin(['min_max_dep_balance_amt']))
    mask_dep = train_full_info.columns.str.startswith('dep_')
    mask_income = train_full_info.columns.str.startswith('income_')
    mask_cnt = train_full_info.columns.str.startswith('cnt_')

    cols_to_delete = []
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_avg_dep].tolist()
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_zp].tolist()
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_agg].tolist()
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_dep].tolist()
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_income].tolist()
    cols_to_delete = cols_to_delete + train_full_info.columns[mask_cnt].tolist()

    cols_to_delete = cols_to_delete + ['cnt_prolong_max_5y', 'app_real_estate_ind', 
     'app_children_cnt', 'app_dependent_cnt', 'app_family_cnt',
     'vehicle_counrty_type_nm', 'used_car_flg', 'app_vehicle_ind',
     'savings_pension_flg', 'savings_broker_flg',
     'customer_age', 'savings_sum_bro_now', 'app_income_app']

    train_full_info = train_full_info.drop(cols_to_delete, axis=1)
    
    return train_full_info

# %%
from collections import defaultdict

def filter_by_variance(df, threshold=0.01, exclude_columns=None):
    """
    Удаляет колонки с дисперсией ниже заданного порога.
    
    Параметры:
    - df: исходный DataFrame
    - threshold: порог дисперсии (по умолчанию 0.01)
    - exclude_columns: список колонок, которые не нужно удалять (например, целевая переменная)
    
    Возвращает:
    - DataFrame без колонок с низкой дисперсией
    """
    if exclude_columns is None:
        exclude_columns = []
    
    # Выбираем только числовые колонки, исключая указанные
    numeric_cols = df.select_dtypes(include=['number']).columns.difference(exclude_columns)
    
    # Вычисляем дисперсию
    variances = df[numeric_cols].var()
    
    # Колонки для удаления
    low_variance_cols = variances[variances < threshold].index.tolist()
    
    # Удаляем колонки с низкой дисперсией
    return df.drop(columns=low_variance_cols)

def filter_by_low_correlation(df, target_col=['id', 'index', 'target'], threshold=0.01):
    """
    Оставляет только колонки с корреляцией (по модулю) выше порога с целевой переменной.
    
    Параметры:
    - df: исходный DataFrame
    - target_col: название целевой колонки
    - threshold: порог корреляции (по умолчанию 0.4)
    
    Возвращает:
    - DataFrame с колонками, имеющими значимую корреляцию с target_col
    """
    
    # Вычисляем корреляцию только для числовых колонок
    numeric_df = df.select_dtypes(include=['number'])
    corr_matrix = numeric_df.corr()
    
    # Получаем корреляцию с целевой переменной
    target_corr = corr_matrix.loc[target_col, :]
    
    # Выбираем колонки с корреляцией выше порога (по модулю)
    significant_cols = target_corr.columns[(target_corr.abs() > threshold).any(axis=0)]

    
    # Оставляем только значимые колонки
    return df[significant_cols]

def remove_temporal_duplicates(df, target_col=None):
    """
    Удаляет временные дубликаты колонок с особым правилом для _now, _1m, _12m:
    - Всегда оставляет _now, _1m и _12m, если они существуют
    - Для остальных временных периодов применяет стандартные правила приоритета
    
    Параметры:
    - df: исходный DataFrame
    - target_col: название колонки, которую нужно сохранить
    
    Возвращает:
    - DataFrame с сохраненными временными колонками
    """
    from collections import defaultdict
    import re
    
    col_groups = defaultdict(list)
    temporal_pattern = re.compile(r'(_now|_\d{1,2}m|_\d{1,2}|_7d)$')
    
    # Группируем колонки по базовым названиям
    for col in df.columns:
        if target_col and col == target_col:
            continue  # Целевую колонку не трогаем
            
        # Ищем временной суффикс
        match = temporal_pattern.search(col)
        if match:
            suffix = match.group()
            base_col = col[:-len(suffix)]
            col_groups[base_col].append((suffix, col))
        else:
            # Колонки без временного суффикса оставляем как есть
            col_groups[col].append(('', col))
    
    cols_to_keep = set()
    cols_to_remove = set()
    
    # Определяем приоритетные суффиксы (которые оставляем все)
    keep_all_suffixes = ['_now', '_1m', '_12m']
    # Стандартные приоритеты для остальных случаев
    standard_priority = ['_now', '_1m', '_1', '_12m', '_12', '_2m', '_2', 
                        '_3m', '_3', '_6m', '_6', '_9m', '_9', '_7d']
    
    for base_col, variants in col_groups.items():
        if len(variants) > 1:  # Если есть временные варианты
            # Проверяем наличие специальных суффиксов
            special_variants = [(suf, col) for suf, col in variants if suf in keep_all_suffixes]
            
            if len(special_variants) >= 1:  # Если есть хотя бы один специальный суффикс
                # Оставляем все специальные суффиксы
                for suf, col in special_variants:
                    cols_to_keep.add(col)
                
                # Удаляем остальные временные варианты для этой группы
                for suf, col in variants:
                    if suf not in keep_all_suffixes:
                        cols_to_remove.add(col)
            else:
                # Применяем стандартные правила приоритета
                sorted_variants = sorted(
                    variants,
                    key=lambda x: standard_priority.index(x[0]) if x[0] in standard_priority 
                    else len(standard_priority)
                )
                # Оставляем колонку с наивысшим приоритетом
                cols_to_keep.add(sorted_variants[0][1])
                # Остальные добавляем на удаление
                for suf, col in sorted_variants[1:]:
                    cols_to_remove.add(col)
    
    # Удаляем дубликаты
    result_df = df.drop(columns=cols_to_remove)
    
    return result_df


def preprocess_data(df, mode='both', nan_threshold=0.7):
    """
    Удаляет колонки с долей пропусков (NaN) выше заданного порога.
    
    Параметры:
        df: Исходный DataFrame.
        mode: Режим обработки:
            - 'both' (по умолчанию): все колонки.
            - 'numeric': только числовые колонки.
            - 'categorical': только категориальные колонки.
        nan_threshold: Доля пропусков для удаления колонки (0.7 = 70%).
    
    Возвращает:
        DataFrame с удаленными колонками.
    """
    # Определяем типы колонок
    numeric_cols = df.select_dtypes(include=['int', 'float']).columns
    categorical_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns
    
    # Выбираем колонки для обработки в зависимости от режима
    if mode == 'numeric':
        cols_to_check = numeric_cols
    elif mode == 'categorical':
        cols_to_check = categorical_cols
    else:  # 'both'
        cols_to_check = df.columns
    
    # Вычисляем порог для удаления
    threshold = len(df) * nan_threshold
    
    # Удаляем колонки с пропусками > порога
    cols_to_drop = [col for col in cols_to_check if df[col].isnull().sum() > threshold]
    df = df.drop(columns=cols_to_drop)
    
    return df


def remove_correlated_features(df, target_col='target', threshold=0.5):
    """
    Удаляет коррелирующие признаки, сохраняя целевую переменную.
    
    Параметры:
        df: Исходный датафрейм.
        target_col: Название столбца с целевой переменной (не удаляется).
        threshold: Порог корреляции для удаления (по умолчанию 0.5).
    
    Возвращает:
        Датафрейм с некоррелирующими признаками и целевой переменной.
    """
    # Отделяем целевую переменную и признаки
    target = df[target_col]
    features = df[df.select_dtypes(include=['number']).columns]
    features = features.drop(columns=[target_col])
    
    # Вычисляем матрицу корреляций
    corr_matrix = features.corr().abs()
    
    # Верхний треугольник матрицы (чтобы не дублировать пары)
    upper = corr_matrix.where(np.triu(np.ones_like(corr_matrix, dtype=bool), k=1))
    
    # Находим признаки для удаления (корреляция > threshold)
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    
    # Удаляем коррелирующие признаки и возвращаем целевой столбец
    filtered_features = features.drop(columns=to_drop)
    return pd.concat([filtered_features, target], axis=1)

# %% [markdown]
# # Обработка данных и модель

# %%
train_main_df = pd.read_parquet('input_data/train_main_df.parquet')
train_target = pd.read_csv('input_data/train_target.csv')

train_target['index'] = train_target.index
train_main_df['index'] = train_main_df.index

train = pd.merge(train_target, train_main_df, on=['id', 'index'])

# %%
train = columns_drop(train)
train = filter_by_variance(train)
train = remove_temporal_duplicates(train)
train = remove_correlated_features(train)
train = filter_by_low_correlation(train, threshold=0.01)

# %%
train.columns
# Out:
# Index(['id', 'index', 'min_max_dep_balance_amt', 'savings_sum_dep_now',
#        'savings_sum_dep_12m', 'savings_sum_sa_now', 'savings_sum_sa_12m',
#        'savings_sum_sa_credit_1m', 'savings_sum_sa_credit_12m',
#        'savings_sum_bro_1m', 'target'],
#       dtype='object')

# %%
train
# Out:
#              id  index  min_max_dep_balance_amt  savings_sum_dep_now  \
# 0      97678374      0                      NaN             0.000000
# 1      62472650      1                      NaN          4963.610840
# 2      94308112      2            130510.773438             0.000000
# 3      68994873      3                57.079170          8969.149414
# 4      78127603      4                      NaN          4500.253906
# ...         ...    ...                      ...                  ...
# 85584   6163462  85584               819.466614          3354.238037
# 85585  22320709  85585              1243.621704          6023.775391
# 85586  23863045  85586                 0.010000             0.000000
# 85587  33408678  85587                 0.010000             0.000000
# 85588  84261968  85588               579.032776          8875.231445
#
#        savings_sum_dep_12m  savings_sum_sa_now  savings_sum_sa_12m  \
# 0                 0.000000        2.645298e+02            0.000000
# 1                 0.000000        2.039230e+02          289.098999
# 2              2376.036621        2.211489e+05       126578.445312
# 3               334.324036        1.529677e+03         8470.016602
# 4                 0.000000        3.650610e+02          207.131500
# ...                    ...                 ...                 ...
# 85584             0.000000        0.000000e+00            0.000000
# 85585           523.401062        1.062631e+06       119322.023438
# 85586          2228.442383        0.000000e+00            0.000000
# 85587           461.857391        2.027054e+05            0.000000
# 85588             0.000000        3.787239e+03            0.000000
#
#        savings_sum_sa_credit_1m  savings_sum_sa_credit_12m  \
# 0                      0.000000               0.000000e+00
# 1                      0.000000               2.163016e+02
# 2                   1472.557983               1.858215e+05
# 3                    166.532135               1.240958e+05
# 4                    183.979782               0.000000e+00
# ...                         ...                        ...
# 85584                290.803802               2.232204e+03
# 85585             236934.421875               2.299806e+06
# 85586                150.719467               0.000000e+00
# 85587             202529.312500               2.039604e+05
# 85588               5040.212402               2.265775e+04
#
#        savings_sum_bro_1m         target
# 0              219.018234       0.000000
# 1                0.000000       0.000000
# 2               54.809654  219932.906250
# 3              171.854828     631.770020
# 4              174.200806       0.000000
# ...                   ...            ...
# 85584           81.305336       0.000000
# 85585          227.499557  841071.000000
# 85586            9.497079      27.990000
# 85587            0.000000       0.000000
# 85588          189.925888    2520.550049
#
# [85589 rows x 11 columns]

# %%
# min_max_dep_balance_amt - Минимальный остаток по всем счетам клиента за последний год (сокращен по причине высокой нагрузки)
# savings_sum_dep_now - Суммарный остаток по продукту Deposit на отчетную дату
# savings_sum_dep_12m - Суммарный остаток по продукту Deposit на отчетную дату минус 12 месяцев
# savings_sum_sa_now - Суммарный остаток по продукту Save_account  на отчетную дату
# savings_sum_sa_12m - Суммарный остаток по продукту Save_account  на отчетную дату минус 12 месяцев
# savings_sum_sa_credit_1m - Сумма поступлений денежных средств на счета с продуктом Save_account  за 1 месяц до отчетной даты
# savings_sum_sa_credit_12m - Сумма поступлений денежных средств на счета с продуктом Save_account  за 12 последних месяцев до отчетной даты
# savings_sum_bro_1m - Суммарный остаток по продукту инвест. (брокерские счета + ИИС)  на отчетную дату минус 1 месяц

# %%
features = train.columns
categorical_features = train[features].select_dtypes(include=['object']).columns
for feature in categorical_features:
    train[feature] = train[feature].astype(str)
categorical_features_indices = np.where(train.dtypes == 'object')[0]

# Разделение данных
X_train, X_test, y_train, y_test = train_test_split(
    train.drop(['id', 'target', 'index'], axis=1),
    train_target['target'], 
    test_size=0.7,
    random_state=42 
)

y_train = np.log1p(y_train)
y_test = np.log1p(y_test)

train_pool = Pool(data = X_train, 
                  label = y_train, 
                  cat_features = categorical_features_indices)

test_pool = Pool(data = X_test, 
                  cat_features = categorical_features_indices)

model = CatBoostRegressor(
    bootstrap_type='MVS',
    grow_policy='Lossguide',
    max_leaves=32,
    min_data_in_leaf=30,
    boosting_type='Plain',
    score_function='L2',
    iterations=300,
    learning_rate=0.05,
    loss_function='RMSE',
    random_seed=42,
    verbose = 1,
    cat_features=categorical_features_indices
)

model.fit(train_pool)
# Out:
# 0:	learn: 5.3945605	total: 178ms	remaining: 53.3s
# 1:	learn: 5.1819814	total: 191ms	remaining: 28.5s
# 2:	learn: 4.9817551	total: 204ms	remaining: 20.2s
# 3:	learn: 4.7932667	total: 214ms	remaining: 15.8s
# 4:	learn: 4.6162079	total: 220ms	remaining: 13s
# 5:	learn: 4.4502712	total: 227ms	remaining: 11.1s
# 6:	learn: 4.2943229	total: 234ms	remaining: 9.79s
# 7:	learn: 4.1486550	total: 241ms	remaining: 8.79s
# 8:	learn: 4.0126945	total: 248ms	remaining: 8.01s
# 9:	learn: 3.8849895	total: 255ms	remaining: 7.38s
# 10:	learn: 3.7665640	total: 262ms	remaining: 6.87s
# 11:	learn: 3.6559510	total: 268ms	remaining: 6.44s
# 12:	learn: 3.5521785	total: 275ms	remaining: 6.07s
# 13:	learn: 3.4555944	total: 282ms	remaining: 5.75s
# 14:	learn: 3.3659702	total: 288ms	remaining: 5.48s
# 15:	learn: 3.2826986	total: 295ms	remaining: 5.24s
# 16:	learn: 3.2054684	total: 302ms	remaining: 5.03s
# 17:	learn: 3.1335985	total: 309ms	remaining: 4.84s
# 18:	learn: 3.0670861	total: 316ms	remaining: 4.67s
# 19:	learn: 3.0056579	total: 323ms	remaining: 4.52s
# 20:	learn: 2.9475364	total: 329ms	remaining: 4.37s
# 21:	learn: 2.8942939	total: 336ms	remaining: 4.24s
# 22:	learn: 2.8455923	total: 342ms	remaining: 4.12s
# 23:	learn: 2.8012705	total: 349ms	remaining: 4.02s
# 24:	learn: 2.7592353	total: 356ms	remaining: 3.92s
# 25:	learn: 2.7211905	total: 363ms	remaining: 3.82s
# 26:	learn: 2.6861294	total: 369ms	remaining: 3.73s
# 27:	learn: 2.6533120	total: 376ms	remaining: 3.65s
# 28:	learn: 2.6239868	total: 383ms	remaining: 3.58s
# 29:	learn: 2.5961070	total: 389ms	remaining: 3.5s
# 30:	learn: 2.5711402	total: 398ms	remaining: 3.46s
# 31:	learn: 2.5478872	total: 406ms	remaining: 3.4s
# 32:	learn: 2.5261623	total: 415ms	remaining: 3.36s
# 33:	learn: 2.5069062	total: 422ms	remaining: 3.3s
# 34:	learn: 2.4886576	total: 428ms	remaining: 3.24s
# 35:	learn: 2.4720362	total: 435ms	remaining: 3.19s
# 36:	learn: 2.4571454	total: 442ms	remaining: 3.14s
# 37:	learn: 2.4431452	total: 448ms	remaining: 3.09s
# 38:	learn: 2.4304765	total: 456ms	remaining: 3.05s
# 39:	learn: 2.4185922	total: 463ms	remaining: 3.01s
# 40:	learn: 2.4077017	total: 470ms	remaining: 2.97s
# 41:	learn: 2.3979753	total: 477ms	remaining: 2.93s
# 42:	learn: 2.3886755	total: 485ms	remaining: 2.9s
# 43:	learn: 2.3801096	total: 494ms	remaining: 2.88s
# 44:	learn: 2.3722823	total: 502ms	remaining: 2.85s
# 45:	learn: 2.3649338	total: 511ms	remaining: 2.82s
# 46:	learn: 2.3580474	total: 519ms	remaining: 2.79s
# 47:	learn: 2.3516102	total: 527ms	remaining: 2.76s
# 48:	learn: 2.3460040	total: 534ms	remaining: 2.74s
# 49:	learn: 2.3406919	total: 542ms	remaining: 2.71s
# 50:	learn: 2.3353817	total: 550ms	remaining: 2.69s
# 51:	learn: 2.3307160	total: 557ms	remaining: 2.66s
# 52:	learn: 2.3264942	total: 563ms	remaining: 2.63s
# 53:	learn: 2.3225343	total: 570ms	remaining: 2.6s
# 54:	learn: 2.3185066	total: 576ms	remaining: 2.57s
# 55:	learn: 2.3150942	total: 583ms	remaining: 2.54s
# 56:	learn: 2.3117216	total: 589ms	remaining: 2.51s
# 57:	learn: 2.3085801	total: 595ms	remaining: 2.48s
# 58:	learn: 2.3055771	total: 601ms	remaining: 2.45s
# 59:	learn: 2.3026421	total: 607ms	remaining: 2.43s
# 60:	learn: 2.2995555	total: 615ms	remaining: 2.41s
# 61:	learn: 2.2972068	total: 622ms	remaining: 2.39s
# 62:	learn: 2.2949584	total: 629ms	remaining: 2.37s
# 63:	learn: 2.2928550	total: 637ms	remaining: 2.35s
# 64:	learn: 2.2907807	total: 644ms	remaining: 2.33s
# 65:	learn: 2.2887190	total: 650ms	remaining: 2.31s
# 66:	learn: 2.2870081	total: 657ms	remaining: 2.28s
# 67:	learn: 2.2852671	total: 664ms	remaining: 2.26s
# 68:	learn: 2.2836032	total: 672ms	remaining: 2.25s
# 69:	learn: 2.2820677	total: 678ms	remaining: 2.23s
# 70:	learn: 2.2802469	total: 685ms	remaining: 2.21s
# 71:	learn: 2.2786220	total: 691ms	remaining: 2.19s
# 72:	learn: 2.2767205	total: 697ms	remaining: 2.17s
# 73:	learn: 2.2747345	total: 703ms	remaining: 2.15s
# 74:	learn: 2.2729893	total: 711ms	remaining: 2.13s
# 75:	learn: 2.2711255	total: 717ms	remaining: 2.11s
# 76:	learn: 2.2697844	total: 724ms	remaining: 2.1s
# 77:	learn: 2.2680349	total: 730ms	remaining: 2.08s
# 78:	learn: 2.2668289	total: 736ms	remaining: 2.06s
# 79:	learn: 2.2650053	total: 743ms	remaining: 2.04s
# 80:	learn: 2.2634805	total: 749ms	remaining: 2.02s
# 81:	learn: 2.2622296	total: 755ms	remaining: 2.01s
# 82:	learn: 2.2609740	total: 762ms	remaining: 1.99s
# 83:	learn: 2.2599093	total: 769ms	remaining: 1.98s
# 84:	learn: 2.2584918	total: 775ms	remaining: 1.96s
# 85:	learn: 2.2579118	total: 781ms	remaining: 1.94s
# 86:	learn: 2.2567163	total: 788ms	remaining: 1.93s
# 87:	learn: 2.2551453	total: 794ms	remaining: 1.91s
# 88:	learn: 2.2538494	total: 799ms	remaining: 1.9s
# 89:	learn: 2.2521000	total: 807ms	remaining: 1.88s
# 90:	learn: 2.2507048	total: 812ms	remaining: 1.86s
# 91:	learn: 2.2491143	total: 819ms	remaining: 1.85s
# 92:	learn: 2.2481369	total: 827ms	remaining: 1.84s
# 93:	learn: 2.2465363	total: 834ms	remaining: 1.83s
# 94:	learn: 2.2449443	total: 839ms	remaining: 1.81s
# 95:	learn: 2.2427808	total: 847ms	remaining: 1.8s
# 96:	learn: 2.2415376	total: 853ms	remaining: 1.79s
# 97:	learn: 2.2400951	total: 860ms	remaining: 1.77s
# 98:	learn: 2.2385598	total: 866ms	remaining: 1.76s
# 99:	learn: 2.2372091	total: 872ms	remaining: 1.74s
# 100:	learn: 2.2353499	total: 877ms	remaining: 1.73s
# 101:	learn: 2.2340945	total: 883ms	remaining: 1.71s
# 102:	learn: 2.2328475	total: 889ms	remaining: 1.7s
# 103:	learn: 2.2316781	total: 895ms	remaining: 1.69s
# 104:	learn: 2.2305604	total: 901ms	remaining: 1.67s
# 105:	learn: 2.2293170	total: 908ms	remaining: 1.66s
# 106:	learn: 2.2281852	total: 914ms	remaining: 1.65s
# 107:	learn: 2.2272607	total: 920ms	remaining: 1.64s
# 108:	learn: 2.2259836	total: 926ms	remaining: 1.62s
# 109:	learn: 2.2249453	total: 932ms	remaining: 1.61s
# 110:	learn: 2.2233927	total: 937ms	remaining: 1.59s
# 111:	learn: 2.2222555	total: 944ms	remaining: 1.58s
# 112:	learn: 2.2213525	total: 950ms	remaining: 1.57s
# 113:	learn: 2.2200565	total: 956ms	remaining: 1.56s
# 114:	learn: 2.2187722	total: 963ms	remaining: 1.55s
# 115:	learn: 2.2179723	total: 969ms	remaining: 1.54s
# 116:	learn: 2.2169107	total: 975ms	remaining: 1.52s
# 117:	learn: 2.2154355	total: 981ms	remaining: 1.51s
# 118:	learn: 2.2149572	total: 987ms	remaining: 1.5s
# 119:	learn: 2.2136910	total: 992ms	remaining: 1.49s
# 120:	learn: 2.2127274	total: 999ms	remaining: 1.48s
# 121:	learn: 2.2114911	total: 1s	remaining: 1.47s
# 122:	learn: 2.2106577	total: 1.01s	remaining: 1.45s
# 123:	learn: 2.2095497	total: 1.02s	remaining: 1.44s
# 124:	learn: 2.2085149	total: 1.02s	remaining: 1.43s
# 125:	learn: 2.2077912	total: 1.03s	remaining: 1.42s
# 126:	learn: 2.2070953	total: 1.03s	remaining: 1.41s
# 127:	learn: 2.2061735	total: 1.04s	remaining: 1.4s
# 128:	learn: 2.2053192	total: 1.05s	remaining: 1.39s
# 129:	learn: 2.2041436	total: 1.06s	remaining: 1.38s
# 130:	learn: 2.2036733	total: 1.06s	remaining: 1.37s
# 131:	learn: 2.2025060	total: 1.07s	remaining: 1.36s
# 132:	learn: 2.2015103	total: 1.08s	remaining: 1.35s
# 133:	learn: 2.2005097	total: 1.08s	remaining: 1.34s
# 134:	learn: 2.2001396	total: 1.09s	remaining: 1.33s
# 135:	learn: 2.1994697	total: 1.09s	remaining: 1.32s
# 136:	learn: 2.1984209	total: 1.1s	remaining: 1.31s
# 137:	learn: 2.1975678	total: 1.1s	remaining: 1.3s
# 138:	learn: 2.1964617	total: 1.11s	remaining: 1.29s
# 139:	learn: 2.1946826	total: 1.12s	remaining: 1.28s
# 140:	learn: 2.1938335	total: 1.12s	remaining: 1.26s
# 141:	learn: 2.1924727	total: 1.13s	remaining: 1.25s
# 142:	learn: 2.1917120	total: 1.13s	remaining: 1.24s
# 143:	learn: 2.1907647	total: 1.14s	remaining: 1.23s
# 144:	learn: 2.1897537	total: 1.15s	remaining: 1.23s
# 145:	learn: 2.1889826	total: 1.15s	remaining: 1.22s
# 146:	learn: 2.1884669	total: 1.16s	remaining: 1.21s
# 147:	learn: 2.1879109	total: 1.16s	remaining: 1.2s
# 148:	learn: 2.1868470	total: 1.17s	remaining: 1.19s
# 149:	learn: 2.1859242	total: 1.18s	remaining: 1.18s
# 150:	learn: 2.1845451	total: 1.18s	remaining: 1.17s
# 151:	learn: 2.1837219	total: 1.19s	remaining: 1.15s
# 152:	learn: 2.1831318	total: 1.19s	remaining: 1.14s
# 153:	learn: 2.1815991	total: 1.2s	remaining: 1.13s
# 154:	learn: 2.1802668	total: 1.2s	remaining: 1.12s
# 155:	learn: 2.1794580	total: 1.21s	remaining: 1.11s
# 156:	learn: 2.1787494	total: 1.21s	remaining: 1.1s
# 157:	learn: 2.1772432	total: 1.22s	remaining: 1.09s
# 158:	learn: 2.1765828	total: 1.22s	remaining: 1.08s
# 159:	learn: 2.1758878	total: 1.23s	remaining: 1.07s
# 160:	learn: 2.1752536	total: 1.23s	remaining: 1.06s
# 161:	learn: 2.1744094	total: 1.24s	remaining: 1.06s
# 162:	learn: 2.1731760	total: 1.25s	remaining: 1.05s
# 163:	learn: 2.1724719	total: 1.25s	remaining: 1.04s
# 164:	learn: 2.1716263	total: 1.26s	remaining: 1.03s
# 165:	learn: 2.1701465	total: 1.26s	remaining: 1.02s
# 166:	learn: 2.1690076	total: 1.27s	remaining: 1.01s
# 167:	learn: 2.1680980	total: 1.28s	remaining: 1s
# 168:	learn: 2.1671966	total: 1.28s	remaining: 994ms
# 169:	learn: 2.1661699	total: 1.29s	remaining: 986ms
# 170:	learn: 2.1652318	total: 1.29s	remaining: 977ms
# 171:	learn: 2.1640982	total: 1.3s	remaining: 967ms
# 172:	learn: 2.1628811	total: 1.3s	remaining: 958ms
# 173:	learn: 2.1622330	total: 1.31s	remaining: 949ms
# 174:	learn: 2.1615367	total: 1.31s	remaining: 940ms
# 175:	learn: 2.1607511	total: 1.32s	remaining: 931ms
# 176:	learn: 2.1604352	total: 1.32s	remaining: 921ms
# 177:	learn: 2.1590771	total: 1.33s	remaining: 913ms
# 178:	learn: 2.1579138	total: 1.34s	remaining: 904ms
# 179:	learn: 2.1574104	total: 1.34s	remaining: 897ms
# 180:	learn: 2.1563154	total: 1.35s	remaining: 889ms
# 181:	learn: 2.1551273	total: 1.36s	remaining: 880ms
# 182:	learn: 2.1541567	total: 1.36s	remaining: 872ms
# 183:	learn: 2.1527509	total: 1.37s	remaining: 864ms
# 184:	learn: 2.1519466	total: 1.38s	remaining: 855ms
# 185:	learn: 2.1507983	total: 1.38s	remaining: 848ms
# 186:	learn: 2.1495384	total: 1.39s	remaining: 840ms
# 187:	learn: 2.1487075	total: 1.4s	remaining: 832ms
# 188:	learn: 2.1479095	total: 1.4s	remaining: 824ms
# 189:	learn: 2.1467369	total: 1.41s	remaining: 816ms
# 190:	learn: 2.1459306	total: 1.42s	remaining: 809ms
# 191:	learn: 2.1451230	total: 1.42s	remaining: 800ms
# 192:	learn: 2.1439789	total: 1.43s	remaining: 793ms
# 193:	learn: 2.1433112	total: 1.44s	remaining: 786ms
# 194:	learn: 2.1423532	total: 1.45s	remaining: 779ms
# 195:	learn: 2.1414604	total: 1.45s	remaining: 771ms
# 196:	learn: 2.1408614	total: 1.46s	remaining: 763ms
# 197:	learn: 2.1401662	total: 1.47s	remaining: 756ms
# 198:	learn: 2.1390186	total: 1.47s	remaining: 748ms
# 199:	learn: 2.1383366	total: 1.48s	remaining: 740ms
# 200:	learn: 2.1372470	total: 1.49s	remaining: 733ms
# 201:	learn: 2.1363115	total: 1.49s	remaining: 725ms
# 202:	learn: 2.1349767	total: 1.5s	remaining: 717ms
# 203:	learn: 2.1341605	total: 1.51s	remaining: 709ms
# 204:	learn: 2.1337490	total: 1.51s	remaining: 701ms
# 205:	learn: 2.1332594	total: 1.52s	remaining: 694ms
# 206:	learn: 2.1324474	total: 1.53s	remaining: 686ms
# 207:	learn: 2.1313059	total: 1.53s	remaining: 679ms
# 208:	learn: 2.1303130	total: 1.54s	remaining: 671ms
# 209:	learn: 2.1295746	total: 1.54s	remaining: 662ms
# 210:	learn: 2.1292729	total: 1.55s	remaining: 654ms
# 211:	learn: 2.1281002	total: 1.56s	remaining: 647ms
# 212:	learn: 2.1278519	total: 1.56s	remaining: 639ms
# 213:	learn: 2.1269397	total: 1.57s	remaining: 630ms
# 214:	learn: 2.1257659	total: 1.57s	remaining: 623ms
# 215:	learn: 2.1249338	total: 1.58s	remaining: 615ms
# 216:	learn: 2.1242859	total: 1.59s	remaining: 607ms
# 217:	learn: 2.1230947	total: 1.59s	remaining: 599ms
# 218:	learn: 2.1218398	total: 1.6s	remaining: 591ms
# 219:	learn: 2.1215871	total: 1.6s	remaining: 583ms
# 220:	learn: 2.1210549	total: 1.61s	remaining: 575ms
# 221:	learn: 2.1199972	total: 1.61s	remaining: 567ms
# 222:	learn: 2.1189002	total: 1.62s	remaining: 560ms
# 223:	learn: 2.1186947	total: 1.63s	remaining: 551ms
# 224:	learn: 2.1177633	total: 1.63s	remaining: 544ms
# 225:	learn: 2.1175604	total: 1.64s	remaining: 536ms
# 226:	learn: 2.1169825	total: 1.64s	remaining: 528ms
# 227:	learn: 2.1158524	total: 1.65s	remaining: 520ms
# 228:	learn: 2.1153137	total: 1.65s	remaining: 512ms
# 229:	learn: 2.1147592	total: 1.66s	remaining: 504ms
# 230:	learn: 2.1133944	total: 1.66s	remaining: 497ms
# 231:	learn: 2.1129112	total: 1.67s	remaining: 489ms
# 232:	learn: 2.1123770	total: 1.67s	remaining: 481ms
# 233:	learn: 2.1117041	total: 1.68s	remaining: 473ms
# 234:	learn: 2.1104033	total: 1.68s	remaining: 466ms
# 235:	learn: 2.1099955	total: 1.69s	remaining: 459ms
# 236:	learn: 2.1086054	total: 1.7s	remaining: 451ms
# 237:	learn: 2.1079844	total: 1.7s	remaining: 444ms
# 238:	learn: 2.1066721	total: 1.71s	remaining: 436ms
# 239:	learn: 2.1054361	total: 1.71s	remaining: 429ms
# 240:	learn: 2.1052025	total: 1.72s	remaining: 421ms
# 241:	learn: 2.1043515	total: 1.73s	remaining: 413ms
# 242:	learn: 2.1033332	total: 1.73s	remaining: 406ms
# 243:	learn: 2.1025810	total: 1.74s	remaining: 398ms
# 244:	learn: 2.1019863	total: 1.74s	remaining: 391ms
# 245:	learn: 2.1018050	total: 1.75s	remaining: 383ms
# 246:	learn: 2.1010760	total: 1.75s	remaining: 376ms
# 247:	learn: 2.1005325	total: 1.76s	remaining: 368ms
# 248:	learn: 2.1000437	total: 1.76s	remaining: 361ms
# 249:	learn: 2.0991919	total: 1.77s	remaining: 353ms
# 250:	learn: 2.0988446	total: 1.77s	remaining: 346ms
# 251:	learn: 2.0979532	total: 1.78s	remaining: 339ms
# 252:	learn: 2.0971920	total: 1.78s	remaining: 331ms
# 253:	learn: 2.0966968	total: 1.79s	remaining: 324ms
# 254:	learn: 2.0958634	total: 1.79s	remaining: 317ms
# 255:	learn: 2.0951953	total: 1.8s	remaining: 309ms
# 256:	learn: 2.0944938	total: 1.8s	remaining: 302ms
# 257:	learn: 2.0938096	total: 1.81s	remaining: 295ms
# 258:	learn: 2.0932624	total: 1.81s	remaining: 287ms
# 259:	learn: 2.0923158	total: 1.82s	remaining: 280ms
# 260:	learn: 2.0918244	total: 1.83s	remaining: 273ms
# 261:	learn: 2.0913683	total: 1.83s	remaining: 266ms
# 262:	learn: 2.0903231	total: 1.84s	remaining: 259ms
# 263:	learn: 2.0896302	total: 1.84s	remaining: 251ms
# 264:	learn: 2.0886678	total: 1.85s	remaining: 244ms
# 265:	learn: 2.0880618	total: 1.85s	remaining: 237ms
# 266:	learn: 2.0869309	total: 1.86s	remaining: 230ms
# 267:	learn: 2.0867133	total: 1.86s	remaining: 223ms
# 268:	learn: 2.0864835	total: 1.87s	remaining: 215ms
# 269:	learn: 2.0856529	total: 1.88s	remaining: 208ms
# 270:	learn: 2.0852162	total: 1.88s	remaining: 201ms
# 271:	learn: 2.0841349	total: 1.89s	remaining: 194ms
# 272:	learn: 2.0835942	total: 1.89s	remaining: 187ms
# 273:	learn: 2.0829781	total: 1.9s	remaining: 180ms
# 274:	learn: 2.0823752	total: 1.91s	remaining: 173ms
# 275:	learn: 2.0814577	total: 1.91s	remaining: 166ms
# 276:	learn: 2.0804192	total: 1.92s	remaining: 159ms
# 277:	learn: 2.0799542	total: 1.92s	remaining: 152ms
# 278:	learn: 2.0789001	total: 1.93s	remaining: 145ms
# 279:	learn: 2.0780946	total: 1.94s	remaining: 138ms
# 280:	learn: 2.0774921	total: 1.94s	remaining: 131ms
# 281:	learn: 2.0772927	total: 1.95s	remaining: 124ms
# 282:	learn: 2.0768137	total: 1.95s	remaining: 117ms
# 283:	learn: 2.0758062	total: 1.96s	remaining: 110ms
# 284:	learn: 2.0747720	total: 1.96s	remaining: 103ms
# 285:	learn: 2.0743772	total: 1.97s	remaining: 96.3ms
# 286:	learn: 2.0739469	total: 1.97s	remaining: 89.4ms
# 287:	learn: 2.0738063	total: 1.98s	remaining: 82.4ms
# 288:	learn: 2.0726259	total: 1.98s	remaining: 75.5ms
# 289:	learn: 2.0721050	total: 1.99s	remaining: 68.6ms
# 290:	learn: 2.0711450	total: 1.99s	remaining: 61.7ms
# 291:	learn: 2.0703574	total: 2s	remaining: 54.8ms
# 292:	learn: 2.0694275	total: 2s	remaining: 47.9ms
# 293:	learn: 2.0686316	total: 2.01s	remaining: 41ms
# 294:	learn: 2.0682674	total: 2.02s	remaining: 34.2ms
# 295:	learn: 2.0673664	total: 2.02s	remaining: 27.3ms
# 296:	learn: 2.0665096	total: 2.03s	remaining: 20.5ms
# 297:	learn: 2.0658222	total: 2.03s	remaining: 13.6ms
# 298:	learn: 2.0650792	total: 2.04s	remaining: 6.81ms
# 299:	learn: 2.0644469	total: 2.04s	remaining: 0us

# %%
# Вычисляем RMSE
rmse = np.sqrt(np.mean((y_test - model.predict(test_pool)) ** 2))
print(f"RMSE: {rmse:.4f}")

# codabench score 2.48
# Out:
# RMSE: 2.3537

# %% [markdown]
# # Инференс

# %%
def predict_balance(min_max_dep_balance_amt, savings_sum_dep_now,
                    savings_sum_dep_12m, savings_sum_sa_now, savings_sum_sa_12m, savings_sum_sa_credit_1m,
                    savings_sum_sa_credit_12m, savings_sum_bro_1m):
    
    input_data = pd.DataFrame([[min_max_dep_balance_amt, savings_sum_dep_now,
                                savings_sum_dep_12m, savings_sum_sa_now, savings_sum_sa_12m, savings_sum_sa_credit_1m,
                                savings_sum_sa_credit_12m, savings_sum_bro_1m]],
                              columns=train.drop(['id', 'target', 'index'], axis=1).columns
    )

    prediction = model.predict(input_data)

    return f"Предполагаемый остаток на счете: {(np.exp(prediction) - 1)[0]}"

# %%
inputs = [
    gr.Slider(0, 500_000, step=1000, value=5000, 
              label="Минимальный остаток по счетам за год (руб)", 
              info="min_max_dep_balance_amt"),
    gr.Slider(0, 2_000_000, step=10000, value=300_000, 
              label="Остаток по депозитам на текущую дату", 
              info="savings_sum_dep_now"),
    gr.Slider(0, 2_000_000, step=10000, value=200_000, 
              label="Остаток по депозитам 12 мес назад (руб)", 
              info="savings_sum_dep_12m"),
    gr.Slider(0, 2_000_000, step=10000, value=300_000, 
              label="Текущий остаток по накопительным счетам (руб)", 
              info="savings_sum_sa_now"),
    gr.Slider(0, 1_000_000, step=10000, value=150_000, 
              label="Остаток по накопительным счетам 12 мес назад (руб)", 
              info="savings_sum_sa_12m"), 
    gr.Slider(0, 500_000, step=5000, value=50_000, 
              label="Поступления на накопительные счета за 1 мес (руб)", 
              info="savings_sum_sa_credit_1m"),
    gr.Slider(0, 2_000_000, step=10000, value=600_000, 
              label="Поступления на накопительные счета за 12 мес (руб)", 
              info="savings_sum_sa_credit_12m"),
    gr.Slider(0, 5_000_000, step=10000, value=1_200_000, 
              label="Суммарный остаток по продукту инвестиций 1 месяц назад", 
              info="savings_sum_bro_1m")
]

title = "Предсказательная модель остатка на счете"
description = "Введите финансовые показатели клиента для анализа и прогнозирования. Все суммы указываются в рублях."

demo = gr.Interface(
    fn=predict_balance,
    inputs=inputs,
    outputs="text",
    title=title,
    description=description
)

demo.launch(inline=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
