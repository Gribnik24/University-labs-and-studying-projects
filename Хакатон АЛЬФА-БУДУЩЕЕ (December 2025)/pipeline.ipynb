# %%
import numpy as np
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nikita\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
class DataPreprocessor:
    """
    Класс для вспомогательных функций преобразования данных
    """
    def __init__(self):
        self.stop_words = set(stopwords.words('russian')) | {'здравствуйте'}
        self.translit_map = {
            'alfabank': 'альфабанк',
            'actions': 'акции',
            'rules': 'правила',
            'alfafuture': 'альфа будущее',
        }

    def clean_text(self, text: str) -> str:
        """Очистка текста"""
        if pd.isna(text):
            return ""

        text = str(text).lower()
        text = re.sub(r'\d+', '', text)
        text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
        text = re.sub(r'[—«»]', '', text)
        text = re.sub(r'\n', ' ', text)
        text = text.replace('ё', 'е')

        text = ' '.join([word for word in text.split() if word not in self.stop_words and len(word) > 2])
        return text

    def translate_translit(self, text: str) -> str:
        """Преобразование транслита в кириллицу где возможно"""
        for eng, rus in self.translit_map.items():
            text = text.replace(eng, rus)
        return text

    def websites_url_splitting(self, url: str) -> str:
        """Разбиение URL на части с улучшенной обработкой"""
        if pd.isna(url):
            return ""

        url_parts = url.split('/')[3:]
        filtered_parts = [part for part in url_parts if 3 < len(part) < 50 and not part.startswith('2')]

        processed_parts = []
        for part in filtered_parts:
            part = part.replace('-', ' ')
            part = self.translate_translit(part)
            processed_parts.append(part)

        return ' '.join(processed_parts)

    def chunk_by_words(self, text):
        """Разбиение на два или три слова"""
        words = str(text).strip().split()
        
        if len(words) <= 3:
            return [' '.join(words)] if words else []
        
        chunks = []
        
        if len(words) % 2 == 0:
            # Для четного количества - просто разбиваем на пары
            chunks = [' '.join(words[i:i+2]) for i in range(0, len(words), 2)]
        else:
            # Для нечетного количества
            if len(words) % 3 == 0:
                # Если делится на 3 без остатка
                chunks = [' '.join(words[i:i+3]) for i in range(0, len(words), 3)]
            else:
                # Разбиваем на тройки, оставляя 4 или 2 слова в конце
                triplets_count = len(words) // 3
                if len(words) % 3 == 1:
                    # Осталось 1 слово - уменьшаем количество троек на 1
                    triplets_count -= 1
                
                # Добавляем тройки
                for i in range(0, triplets_count * 3, 3):
                    chunks.append(' '.join(words[i:i+3]))
                
                # Обрабатываем оставшиеся слова
                remaining = words[triplets_count * 3:]
                
                if len(remaining) == 4:
                    chunks.append(' '.join(remaining[:2]))
                    chunks.append(' '.join(remaining[2:]))
                elif len(remaining) == 2:
                    chunks.append(' '.join(remaining))
                elif len(remaining) == 1:
                    # Добавляем к последнему чанку
                    chunks[-1] = chunks[-1] + ' ' + remaining[0]
        
        return chunks

# %%
class DataTransformer(DataPreprocessor):
    """
    Класс для преобразования данных
    """
    def __init__(self, questions_df: pd.DataFrame, websites_df: pd.DataFrame):
        super().__init__()
        self.questions_df = questions_df.copy()
        self.websites_df = websites_df.copy()

    def transform_questions(self) -> pd.DataFrame:
        """Трансформация вопросов"""
        self.questions_df['query_cleaned'] = self.questions_df['query'].apply(self.clean_text).apply(lambda x: self.chunk_by_words(x))
        return self.questions_df
    
    def transform_websites(self) -> pd.DataFrame:
        """Трансформация веб-сайтов"""
        self.websites_df['title_cleaned'] = self.websites_df['title'].apply(self.clean_text).apply(lambda x: self.chunk_by_words(x))
        self.websites_df['text_cleaned'] = self.websites_df['text'].apply(self.clean_text).apply(lambda x: self.chunk_by_words(x))
        self.websites_df['url_cleaned'] = self.websites_df['url'].apply(self.websites_url_splitting).apply(lambda x: self.chunk_by_words(x))
    
        self.websites_df['website_all_data'] = self.websites_df['title_cleaned'] + self.websites_df['text_cleaned'] + self.websites_df['url_cleaned']
    
        return self.websites_df

# %%
def pool(hidden_state, mask, pooling_method="cls"):
    """Пулинг эмбеддингов"""
    if pooling_method == "mean":
        s = torch.sum(hidden_state * mask.unsqueeze(-1).float(), dim=1)
        d = mask.sum(axis=1, keepdim=True).float()
        return s / d
    elif pooling_method == "cls":
        return hidden_state[:, 0]
    elif pooling_method == "max":
        return torch.max(hidden_state * mask.unsqueeze(-1).float(), dim=1)[0]
        
class TransformersPredictionPipeline:
    """Класс с моделью на основе transformers"""
    def __init__(self, model_name="ai-forever/ru-en-RoSBERTa", pooling_method="cls"):
        print(f"Загрузка модели: {model_name}")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(model_name)
        self.pooling_method = pooling_method
        self.model.eval()  # Переводим модель в режим оценки
        print("Модель загружена!")

    def encode_texts(self, texts: list) -> torch.Tensor:
        """Кодирование списка текстов в эмбеддинги"""
        print(f"Кодируем {len(texts)} текстов...")

        # Токенизация
        tokenized_inputs = self.tokenizer(
            texts,
            max_length=512,
            padding=True,
            truncation=True,
            return_tensors="pt"
        )

        # Получение эмбеддингов
        with torch.no_grad():
            outputs = self.model(**tokenized_inputs)

        # Применяем пулинг
        embeddings = pool(
            outputs.last_hidden_state,
            tokenized_inputs["attention_mask"],
            pooling_method=self.pooling_method
        )

        # Нормализуем эмбеддинги
        embeddings = F.normalize(embeddings, p=2, dim=1)

        return embeddings

    def fit_predict_pairs(self, questions_df: pd.DataFrame, websites_df: pd.DataFrame,
                          query_column='query_cleaned',
                          website_column='website_all_data',
                          k=5) -> list:

        print("Кодирование текстов и вычисление схожести...")

        # Получаем тексты для кодирования
        queries = questions_df[query_column].tolist()
        websites_texts = websites_df[website_column].tolist()

        # Сохраняем ID и URL для результатов
        self.question_ids = questions_df['q_id'].tolist()
        self.website_ids = websites_df['web_id'].tolist()
        self.website_urls = websites_df['url'].tolist()

        print(f"Кодируем {len(queries)} вопросов...")
        questions_emb = self.encode_texts(queries)

        print(f"Кодируем {len(websites_texts)} сайтов...")
        websites_emb = self.encode_texts(websites_texts)

        print("Вычисляем схожесть...")

        # Вычисляем косинусную схожесть
        scores = questions_emb @ websites_emb.T  # Матрица схожести

        # Обрабатываем результаты
        results = []
        for i, query in enumerate(queries):
            query_scores = scores[i].cpu().tolist()

            # Комбинируем веб-сайты, URLs и scores
            doc_score_pairs = list(zip(self.website_ids, self.website_urls, websites_texts, query_scores))

            # Сортируем по убыванию score
            doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[3], reverse=True)

            # Сохраняем топ-N результатов
            top_results = []
            for web_id, url, doc_text, score in doc_score_pairs[:k]:
                top_results.append({
                    'web_id': web_id,
                    'url': url,
                    'score': score,
                    'text': doc_text[:200] + '...' if len(doc_text) > 200 else doc_text
                })

            results.append({
                'q_id': self.question_ids[i],
                'query': query,
                'web_list': top_results
            })

        print("Готово!")
        return results

    def fit_predict_pairs_advanced(self, questions_df: pd.DataFrame, websites_df: pd.DataFrame,
                                 k=5, weights=(0.5, 0.3, 0.2)) -> list:
        """
        Расширенный метод с раздельным кодированием разных типов текста
        """
        print("Расширенное кодирование текстов...")

        queries = questions_df['query_cleaned'].tolist()

        # Разделяем данные веб-сайтов
        titles = websites_df['title_cleaned'].tolist()
        url_texts = websites_df['url_cleaned'].tolist()
        main_texts = websites_df['text_cleaned'].tolist()

        self.question_ids = questions_df['q_id'].tolist()
        self.website_ids = websites_df['web_id'].tolist()
        self.website_urls = websites_df['url'].tolist()

        print("Кодируем разные типы данных...")

        # Кодируем раздельно
        queries_emb = self.encode_texts(queries)
        titles_emb = self.encode_texts(titles)
        urls_emb = self.encode_texts(url_texts)
        texts_emb = self.encode_texts(main_texts)

        print("Вычисляем комбинированную схожесть...")

        title_weight, url_weight, text_weight = weights

        results = []
        for i, query in enumerate(queries):
            # Вычисляем схожести для разных типов данных
            title_scores = (queries_emb[i] @ titles_emb.T).cpu().tolist()
            url_scores = (queries_emb[i] @ urls_emb.T).cpu().tolist()
            text_scores = (queries_emb[i] @ texts_emb.T).cpu().tolist()

            # Комбинируем scores с весами
            combined_scores = []
            for j in range(len(title_scores)):
                combined_score = (title_scores[j] * title_weight +
                                url_scores[j] * url_weight +
                                text_scores[j] * text_weight)
                combined_scores.append(combined_score)

            # Формируем результаты
            doc_score_pairs = list(zip(self.website_ids, self.website_urls,
                                     titles, combined_scores))
            doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[3], reverse=True)

            top_results = []
            for web_id, url, title, score in doc_score_pairs[:k]:
                top_results.append({
                    'web_id': web_id,
                    'url': url,
                    'score': score,
                    'title': title
                })

            results.append({
                'q_id': self.question_ids[i],
                'query': query,
                'web_list': top_results
            })

        return results

    def get_top_k_dataframe(self, pairs_results: list = None, k: int = 5) -> pd.DataFrame:
        """
        Создает датафрейм с id вопроса и топ-k наиболее подходящих ссылок
        """
        results = []
        for pair_result in pairs_results:
            q_id = pair_result['q_id']
            top_websites = pair_result['web_list'][:k]

            urls = [website['web_id'] for website in top_websites]

            results.append({
                'q_id': q_id,
                'web_list': urls
            })

        return pd.DataFrame(results)

# %%
# Загрузка данных
questions = pd.read_csv('questions_clean.csv', delimiter=',', encoding='utf-8')[:20]
websites = pd.read_csv('websites_updated.csv', delimiter=',', encoding='utf-8')[:20]
websites = websites.dropna(axis=0)

# %%
questions.head()
# Out:
#    q_id                                              query
# 0     1                                        Номер счета
# 1     2                              Где узнать бик и счёт
# 2     3  Мне не приходят коды для подтверждения данной ...
# 3     4  Оформила рассрочку ,но уведомлений никаких не ...
# 4     5  Здравствуйте, когда смогу пользоваться кредитн...

# %%
websites.head()
# Out:
#    web_id                                   url  kind  \
# 0       1                  https://alfabank.ru/  html
# 1       2           https://alfabank.ru/a-club/  html
# 2       3  https://alfabank.ru/a-club/ultimate/  html
# 3       4    https://alfabank.ru/actions/rules/  html
# 4       5       https://alfabank.ru/alfafuture/  html
#
#                                                title  \
# 0  Альфа-Банк - кредитные и дебетовые карты, кред...
# 1                      А-Клуб. Деньги имеют значение
# 2                      А-Клуб. Деньги имеют значение
# 3                                   Скидки по картам
# 4  Альфа‑Будущее: Платформа для развития студенто...
#
#                                                 text
# 0  Рассчитайте выгоду\nРасчёт калькулятора предва...
# 1  Брокерские услуги\nОткрытие брокерского счёта ...
# 2  Хотите получить больше информации?\nПозвоните ...
# 3  Правила проведения Акции «Альфа Пятница. Бараб...
# 4  Образование\nМагистратуры\nМагистратура ВШЭ\nМ...

# %%
# Преобразование данных
transformer = DataTransformer(questions, websites)
questions_cleaned = transformer.transform_questions()
websites_cleaned = transformer.transform_websites()

# %%
questions_cleaned.head()
# Out:
#    q_id                                              query  \
# 0     1                                        Номер счета
# 1     2                              Где узнать бик и счёт
# 2     3  Мне не приходят коды для подтверждения данной ...
# 3     4  Оформила рассрочку ,но уведомлений никаких не ...
# 4     5  Здравствуйте, когда смогу пользоваться кредитн...
#
#                                       query_cleaned
# 0                                     [номер счета]
# 1                                 [узнать бик счет]
# 2    [приходят коды подтверждения, данной операции]
# 3  [оформила рассрочку уведомлений, никаких пришло]
# 4            [смогу пользоваться, кредитной картой]

# %%
websites_cleaned.head()
# Out:
#    web_id                                   url  kind  \
# 0       1                  https://alfabank.ru/  html
# 1       2           https://alfabank.ru/a-club/  html
# 2       3  https://alfabank.ru/a-club/ultimate/  html
# 3       4    https://alfabank.ru/actions/rules/  html
# 4       5       https://alfabank.ru/alfafuture/  html
#
#                                                title  \
# 0  Альфа-Банк - кредитные и дебетовые карты, кред...
# 1                      А-Клуб. Деньги имеют значение
# 2                      А-Клуб. Деньги имеют значение
# 3                                   Скидки по картам
# 4  Альфа‑Будущее: Платформа для развития студенто...
#
#                                                 text  \
# 0  Рассчитайте выгоду\nРасчёт калькулятора предва...
# 1  Брокерские услуги\nОткрытие брокерского счёта ...
# 2  Хотите получить больше информации?\nПозвоните ...
# 3  Правила проведения Акции «Альфа Пятница. Бараб...
# 4  Образование\nМагистратуры\nМагистратура ВШЭ\nМ...
#
#                                        title_cleaned  \
# 0  [альфабанк кредитные дебетовые, карты кредиты ...
# 1                     [аклуб деньги, имеют значение]
# 2                     [аклуб деньги, имеют значение]
# 3                                    [скидки картам]
# 4  [альфа‑будущее платформа развития, студентов у...
#
#                                         text_cleaned        url_cleaned  \
# 0  [рассчитайте выгоду расчет, калькулятора предв...                 []
# 1  [брокерские услуги, открытие брокерского, счет...           [a club]
# 2  [хотите получить информации, позвоните нам отв...  [a club ultimate]
# 3  [правила проведения акции, альфа пятница бараб...    [акции правила]
# 4  [образование магистратуры, магистратура вшэ, м...    [альфа будущее]
#
#                                     website_all_data
# 0  [альфабанк кредитные дебетовые, карты кредиты ...
# 1  [аклуб деньги, имеют значение, брокерские услу...
# 2  [аклуб деньги, имеют значение, хотите получить...
# 3  [скидки картам, правила проведения акции, альф...
# 4  [альфа‑будущее платформа развития, студентов у...

# %%
websites_cleaned['website_all_data'].tolist()
# Out:
# [['альфабанк кредитные дебетовые',
#   'карты кредиты наличными',
#   'автокредитование ипотека другие',
#   'банковские услуги физическим',
#   'юридическим лицам альфабанк',
#   'рассчитайте выгоду расчет',
#   'калькулятора предварительный персональные',
#   'условия сможете узнать',
#   'оформления заявки получайте',
#   'альфабанком сервисы курсы',
#   'валют валюта покупка',
#   'продажа доллар сша',
#   'usd евро eur',
#   'китайский юань cny',
#   'валют информация курсах',
#   'обмена иностранных валют',
#   'является справочной меняться',
#   'течение дня точную',
#   'информацию курсах узнать',
#   'интернетбанке список отделений',
#   'доступен ссылке'],
#  ['аклуб деньги',
#   'имеют значение',
#   'брокерские услуги',
#   'открытие брокерского',
#   'счета приложении',
#   'альфа‑инвестиции расширенный',
#   'инструментарий биржевая',
#   'внебиржевая маржинальная',
#   'торговля биржевые',
#   'структурные облигации',
#   'первичные размещения',
#   'инвестиционное консультирование',
#   'инвесторов брокерским',
#   'счетом альфа‑инвестициях',
#   'привлекательные условия',
#   'автоматизированная консультационная',
#   'платформа альтернативные',
#   'инвестиции инвестирование',
#   'фонды недвижимости',
#   'private equity',
#   'венчурные фонды',
#   'капитал быстрорастущих',
#   'компаний страховые',
#   'пенсионные программы',
#   'инвестиционное накопительное',
#   'страхование жизни',
#   'дополнительные юридические',
#   'налоговые преимущества',
#   'структурирование передачи',
#   'капитала альфа‑капитал',
#   'индивидуальные готовые',
#   'стратегии открытые',
#   'пифы бпифы',
#   'простого эффективного',
#   'доступа рынок',
#   'зпифы структурирования',
#   'капитала реализации',
#   'индивидуальных стратегий',
#   'управления благосостоянием',
#   'индивидуальные решения',
#   'структурирование активов',
#   'рубежом создание',
#   'сложных финансовых',
#   'продуктов запросу',
#   'депозиты накопительные',
#   'счета возможность',
#   'установления индивидуальных',
#   'тарифов банковские',
#   'карты возможность',
#   'привязать карты',
#   'счетам валютах',
#   'карты привилегиями',
#   'кэшбэком драгоценные',
#   'металлы камни',
#   'мерные стандартные',
#   'слитки золота',
#   'бриллианты инвестиционного',
#   'качества сделки',
#   'аккредитив депозитарий',
#   'безопасность гарантия',
#   'сделок любой',
#   'сложности биометрический',
#   'депозитарий усиленное',
#   'круглосуточное хранилище',
#   'кредитование ипотека',
#   'паспорту срок',
#   'лет строящееся',
#   'готовое жилье',
#   'включая рефинансирование',
#   'платежные аксессуары',
#   'керамические платежные',
#   'кольца бесконтакной',
#   'оплатой перевозка',
#   'доставка инкассация',
#   'наличных своя',
#   'служба инкассации',
#   'лучший сервис',
#   'private banking',
#   'версии frank',
#   'лучший российский',
#   'банк состоятельных',
#   'клиентов версии',
#   'wealth navigator',
#   'лучший private',
#   'banking номинациях',
#   'версии euromoney',
#   'частые вопросы',
#   'минимальная максимальная',
#   'сумма пополнения',
#   'брокерского счета',
#   'клиентов возрасте',
#   'лет хотите',
#   'получить информации',
#   'свяжитесь нами',
#   'ответим вопросы',
#   'aclubalfabankru альфабанк',
#   'официальный сайт',
#   'генеральная лицензия',
#   'банка россии',
#   'января альфабанк',
#   'является участником',
#   'системы обязательного',
#   'страхования вкладов',
#   'информация процентных',
#   'ставках договорам',
#   'банковского вклада',
#   'физическими лицами',
#   'центр раскрытия',
#   'корпоративной информации',
#   'информация профессионального',
#   'участника рынка',
#   'ценных бумаг',
#   'информация лицах',
#   'контролем либо',
#   'значительным влиянием',
#   'которых находится',
#   'банк каланчевская',
#   'москва альфабанк',
#   'использует файлы',
#   'cookie целью',
#   'персонализации сервисов',
#   'повышения удобства',
#   'пользования вебсайтом',
#   'хотите ваши',
#   'пользовательские данные',
#   'обрабатывались пожалуйста',
#   'ограничьте использование',
#   'своем браузере',
#   'альфабанк является',
#   'оператором обработке',
#   'персональных данных',
#   'информация обработке',
#   'персональных данных',
#   'сведения реализуемых',
#   'требованиях защите',
#   'персональных данных',
#   'отражены политике',
#   'отношении обработки',
#   'персональных данных',
#   'a club'],
#  ['аклуб деньги',
#   'имеют значение',
#   'хотите получить информации',
#   'позвоните нам ответим',
#   'вопросы aclubalfabankru альфабанк',
#   'официальный сайт генеральная',
#   'лицензия банка россии',
#   'января альфабанк является',
#   'участником системы обязательного',
#   'страхования вкладов информация',
#   'процентных ставках договорам',
#   'банковского вклада физическими',
#   'лицами центр раскрытия',
#   'корпоративной информации информация',
#   'профессионального участника рынка',
#   'ценных бумаг информация',
#   'лицах контролем либо',
#   'значительным влиянием которых',
#   'находится банк каланчевская',
#   'москва альфабанк использует',
#   'файлы cookie целью',
#   'персонализации сервисов повышения',
#   'удобства пользования вебсайтом',
#   'хотите ваши пользовательские',
#   'данные обрабатывались пожалуйста',
#   'ограничьте использование своем',
#   'браузере альфабанк является',
#   'оператором обработке персональных',
#   'данных информация обработке',
#   'персональных данных сведения',
#   'реализуемых требованиях защите',
#   'персональных данных отражены',
#   'политике отношении обработки',
#   'персональных данных',
#   'a club ultimate'],
#  ['скидки картам',
#   'правила проведения акции',
#   'альфа пятница барабан',
#   'суперкэшбэка кэшбэком рив',
#   'гош правила проведения',
#   'акции кэшбэк покупку',
#   'железнодорожных билетов сервисе',
#   'альфа тревел правила',
#   'проведения акции альфа‑баллов',
#   'оформление карты сайте',
#   'автодор новых',
#   'клиентов архив',
#   'акции правила'],
#  ['альфа‑будущее платформа развития',
#   'студентов университетов',
#   'всей россии',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее'],
#  ['дневник',
#   'альфа‑банк занял место',
#   'одном главных молодежных',
#   'рейтингов best company',
#   'award changellenge победили',
#   'сразу нескольких номинациях',
#   'стали лучшими среди',
#   'банков работодатель itсфере',
#   'техническим специальностям стали',
#   'прорывом года настолько',
#   'ярким наш это',
#   'альфа‑банк первым стране',
#   'получил статус работодатель',
#   'нового поколения самый',
#   'технологичный банк changellenge',
#   'презентовала результаты исследования',
#   'best company award',
#   'котором приняли участие',
#   'тысяч студентов ведущих',
#   'вузов россии лучшие',
#   'молодые специалисты всей',
#   'страны мечтают начать',
#   'карьеру вместе альфа‑банком',
#   'changellenge best company',
#   'award это ежегодная',
#   'премия сфере развития',
#   'бренда работодателя которая',
#   'проводится году студенты',
#   'высоким потенциалом онлайнопросе',
#   'показывают относятся работодателям',
#   'страны исследование охватывает',
#   'такие вузы мгу',
#   'мгту мгимо ниу',
#   'вшэ рэу плеханова',
#   'мфти правительстве урфу',
#   'нгу кфу другие',
#   'престижные вузы останавливаться',
#   'планируем присоединяйтесь командам',
#   'лучшего банка старта',
#   'карьеры образование магистратуры',
#   'магистратура вшэ магистратура',
#   'мфти магистратура рудн',
#   'магистратура итмо сетевая',
#   'магистратура кампус онлайнпрактика',
#   'онлайнкурсы дпо преподавателей',
#   'дпо продуктовому подходу',
#   'кампус джуниор альфа‑лаб',
#   'alfa digital school',
#   'гранты стипендии стипендии',
#   'студентам гранты студентам',
#   'гранты преподавателям мероприятия',
#   'чемпионат сочи фест',
#   'экскурсии офисе молодежный',
#   'финтехмитап alfa hack',
#   'карьера вакансии опыта',
#   'амбассадоры менторство стажировки',
#   'партнерства стать партнером',
#   'поддержка карта сайта',
#   'альфа будущее blog',
#   'альфабанк luchshiy bank',
#   'dlya starta karery'],
#  ['дневник',
#   'августе владивостоке завершился',
#   'кейсчемпионат молодежной программы',
#   'finopolis это большое',
#   'соревнование рамках форума',
#   'инновационных финансовых технологий',
#   'взяли интервью победителей',
#   'команды альфа‑тим марии',
#   'горячкиной кирилла жильцова',
#   'артема анискевича узнать',
#   'это значительно доработали',
#   'наше решение точки',
#   'зрения погружения техническую',
#   'часть изучили законодательные',
#   'акты существующие продукты',
#   'альфы ходу погружения',
#   'поняли часть предлагаемых',
#   'функций косвенно реализована',
#   'поэтому отказались процесс',
#   'дал нам инсайты',
#   'доработки решения региональном',
#   'этапе наше решение',
#   'состояло общих концепций',
#   'дополнительного ресерча проведения',
#   'интервью доработали наше',
#   'решение предложили четко',
#   'сформулированных улучшений каждый',
#   'занимается получается нужно',
#   'пытаться заставить страуса',
#   'летать пусть дальше',
#   'бегает задачи должны',
#   'распределяться членами команды',
#   'знаниям определенной отрасли',
#   'наметили регулярный план',
#   'работы менторами проектом',
#   'следовали делать постепенно',
#   'качественно последний момент',
#   'получится это позволит',
#   'сделать качественный проработанный',
#   'продукт прислушиваться стороннему',
#   'мнению долго работаешь',
#   'проектом глаз замыливается',
#   'можешь увидеть очевидные',
#   'недочеты поэтому важно',
#   'прислушиваться чужому мнению',
#   'это менторы проект',
#   'максимально проработанным удовлетворяющим',
#   'потребности клиента нужно',
#   'прислушиваться критике воспринимать',
#   'возможность сделать свой',
#   'проект возможность убедить',
#   'человека своей правоте',
#   'наше путешествие началось',
#   'аэропорту встретились альфа‑тим',
#   'машей кириллом нашим',
#   'наставником александром осиповым',
#   'постоянно шутили обсуждали',
#   'приедем сочи будем',
#   'показывать узнавали друг',
#   'друга самолетах отдыхали',
#   'набраться сил финалом',
#   'восстановиться сочи командой',
#   'ехали знакомые обратно',
#   'поехали друзья сочи',
#   'первую очередь поразило',
#   'аэропорт находится практически',
#   'городе вышли терминала',
#   'увидели пальмы заснеженные',
#   'вершины гор это',
#   'просто сломало представления',
#   'климате наставники альфы',
#   'научили искать нужную',
#   'информацию нужные инструменты',
#   'проектирования продукта также',
#   'научили правильно подавать',
#   'идею публики это',
#   'интересно понятно наставник',
#   'александр осипов научил',
#   'критически оценивать каждую',
#   'мысль правильно переносить',
#   'слова резких некорректных',
#   'формулировок также научил',
#   'регулярной командной работе',
#   'извлечению выгоды критики',
#   'отучил спорить защищать',
#   'неправильные решения взаимоотношения',
#   'наставниками прекрасными оперативно',
#   'отвечали наши вопросы',
#   'направляли связи общение',
#   'ними проходило равных',
#   'какогото взгляда сверху',
#   'вниз общий язык',
#   'находили легко несмотря',
#   'разницу возрасте общаться',
#   'легко приятно недопониманий',
#   'неловких пауз работать',
#   'ними эффективно весело',
#   'приятно общаться единомышленниками',
#   'людьми которые заинтересованы',
#   'улучшении мира доведении',
#   'проектов конца очень',
#   'сдружились время чемпионата',
#   'ходили ресторан общались',
#   'другими альфа‑тим наставниками',
#   'неформальные темы узнавали',
#   'живется других частях',
#   'россии договорились ездить',
#   'друг другу гости',
#   'просто очень провели',
#   'время осознать жюри',
#   'это такие простые',
#   'люди которые когдато',
#   'твоем месте нужно',
#   'заново миллионный прогонять',
#   'материал переживать главное',
#   'найти силы успокоиться',
#   'дальше просто нужно',
#   'бояться выйти получить',
#   'удовольствие своего выступления',
#   'мозг автомате выдаст',
#   'заранее заученную информацию',
#   'нужно обращать внимание',
#   'публику бояться смотреть',
#   'глаза жюри будущее',
#   'могу сказать ораторское',
#   'искусство это очень',
#   'важно стоит пренебрегать',
#   'это очень сильный',
#   'инструмент убеждения жюри',
#   'думаю продолжим развивать',
#   'навык наше выступление',
#   'просто хорошим питчингом',
#   'интересным шоу нам',
#   'очень понравилось работать',
#   'альфой отзывчивые наставники',
#   'настоящие профессионалы своего',
#   'дела грамотно направляли',
#   'научили многим новым',
#   'инструментам product management',
#   'которых знали готовы',
#   'нам помочь выслушать',
#   'это делали искренним',
#   'интересом хочу работать',
#   'команде таких людей',
#   'поскольку работа ними',
#   'превращается хобби поэтому',
#   'уверен воспользуюсь фасттреком',
#   'стажировку приложу усилия',
#   'полноценно закрепиться альфе',
#   'поскольку альфа делает',
#   'лучшее будущее хочу',
#   'делать лучшее будущее',
#   'работать работать работать',
#   'чегото добиться необходимо',
#   'систематически вкладываться дело',
#   'это легче делать',
#   'любишь свое дело',
#   'поэтому нужно найти',
#   'любишь работа приносила',
#   'материальные плоды духовные',
#   'необходимо создать систему',
#   'подготовки следовать отклоняться',
#   'также важна хорошая',
#   'команда которая гореть',
#   'делом нужно выкладываться',
#   'полностью этим повезло',
#   'альфа наставники однокурсники',
#   'двфу всем выражаю',
#   'благодарность проделанную работу',
#   'дальше образование магистратуры',
#   'магистратура вшэ магистратура',
#   'мфти магистратура рудн',
#   'магистратура итмо сетевая',
#   'магистратура кампус онлайнпрактика',
#   'онлайнкурсы дпо преподавателей',
#   'дпо продуктовому подходу',
#   'кампус джуниор альфа‑лаб',
#   'alfa digital school',
#   'гранты стипендии стипендии',
#   'студентам гранты студентам',
#   'гранты преподавателям мероприятия',
#   'чемпионат сочи фест',
#   'экскурсии офисе молодежный',
#   'финтехмитап alfa hack',
#   'карьера вакансии опыта',
#   'амбассадоры менторство стажировки',
#   'партнерства стать партнером',
#   'поддержка карта сайта',
#   'альфа будущее',
#   'blog alfatim',
#   'na finopolis365'],
#  ['дневник',
#   'нужно подготовиться',
#   'этому пути',
#   'задать правильные',
#   'вопросы изучи',
#   'спланируй действуй',
#   'этому учат',
#   'вебинарах личных',
#   'финансах проекта',
#   'финтрек банка',
#   'россии именно',
#   'начинать опыта',
#   'разработать эффективный',
#   'план развития',
#   'делать меньше',
#   'ошибаться свернуть',
#   'пути становится',
#   'сложно спикеры',
#   'татьяна тихонова',
#   'директор департамента',
#   'кадровой политики',
#   'банка россии',
#   'марат исмагулов',
#   'hrдиректор альфа‑банка',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее blog',
#   'kak dostich',
#   'karernogo uspeha'],
#  ['дневник',
#   'преподаватели регионов',
#   'россии завершили',
#   'бесплатный курс',
#   'современный искусственный',
#   'интеллект высшей',
#   'школе альфа‑банка',
#   'итмо курс',
#   'включал видеолекции',
#   'онлайнконсультации мастерклассы',
#   'экспертов альфы',
#   'санктпетербурге преподаватели',
#   'защитили командные',
#   'проекты обменялись',
#   'опытом позволит',
#   'внедрять образовательные',
#   'программы применять',
#   'современные инструменты',
#   'работе подробнее',
#   'свой опыт',
#   'взаимодейтствия участники',
#   'рассказали нам',
#   'интервью центре',
#   'образовательных разработок',
#   'основе технологий',
#   'тюмгу активно',
#   'занимаемся проектами',
#   'интеграции образовательный',
#   'процесс готовы',
#   'делиться нашим',
#   'опытом коллегами',
#   'обучение станет',
#   'отличным подспорьем',
#   'реализации новых',
#   'проектов искусственный',
#   'интеллект это',
#   'просто генератор',
#   'изображений котиками',
#   'инструмент написания',
#   'обобщающих конспектов',
#   'огромный потенциал',
#   'применен сферах',
#   'деятельности главное',
#   'эта технология',
#   'доступна обучаться',
#   'экспериментировать эта',
#   'тема актуальна',
#   'преподавания молодые',
#   'экономисты стремятся',
#   'принимать решения',
#   'основе анализа',
#   'больших объемов',
#   'информации решения',
#   'профессиональных научных',
#   'задач занимаюсь',
#   'моделированием разработки',
#   'нефтяных месторождений',
#   'планирую внедрить',
#   'некоторые аспекты',
#   'свои курсы',
#   'такие data',
#   'culture инструментальные',
#   'методы обработки',
#   'анализа экономических',
#   'данных это',
#   'поможет понимать',
#   'своих коллег',
#   'отвечающих применение',
#   'конкретных методов',
#   'машинного обучения',
#   'научных исследованиях',
#   'поразила организация',
#   'обучения привезти',
#   'преподавателей разных',
#   'уголков страны',
#   'обеспечить размещение',
#   'выстроить программу',
#   'могли максимально',
#   'сосредоточиться учебе',
#   'качественно отдохнуть',
#   'это действительно',
#   'впечатляет разрабатываю',
#   'курс искусственный',
#   'интеллект журналистика',
#   'студентов примерно',
#   'года назад',
#   'стало очевидно',
#   'это будущее',
#   'реальность сторонник',
#   'эпоху цифровых',
#   'технологий учить',
#   'писать бересте',
#   'поэтому начала',
#   'постепенно изучать',
#   'нейросети также',
#   'интеграцию медиа',
#   'существующие кейсы',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее blog',
#   'obuchenie ii',
#   'dlya prepodavateley'],
#  ['дневник',
#   'студентов рэу плеханова',
#   'локация глубокого изучения',
#   'бизнеса провели первых',
#   'гостей панельную дискуссию',
#   'практикующими предпринимателями разбор',
#   'фильма волк уоллстрит',
#   'режиссером экспертами предпринимательству',
#   'инвестициям кого это',
#   'сделали студентов плешки',
#   'которые хотят посещать',
#   'профильные лекции мероприятия',
#   'учиться экспертов альфа‑банка',
#   'чему будем учить',
#   'аналитике исследованию рынка',
#   'финансовому планированию работе',
#   'гипотезами запуску пилотов',
#   'позиционированию маркетингу нам',
#   'помогает фабрика жвачки',
#   'команда которая создает',
#   'отраслевые решения малого',
#   'микробизнеса принять участие',
#   'следи новостями каналах',
#   'университета образование магистратуры',
#   'магистратура вшэ магистратура',
#   'мфти магистратура рудн',
#   'магистратура итмо сетевая',
#   'магистратура кампус онлайнпрактика',
#   'онлайнкурсы дпо преподавателей',
#   'дпо продуктовому подходу',
#   'кампус джуниор альфа‑лаб',
#   'alfa digital school',
#   'гранты стипендии стипендии',
#   'студентам гранты студентам',
#   'гранты преподавателям мероприятия',
#   'чемпионат сочи фест',
#   'экскурсии офисе молодежный',
#   'финтехмитап alfa hack',
#   'карьера вакансии опыта',
#   'амбассадоры менторство стажировки',
#   'партнерства стать партнером',
#   'поддержка карта сайта',
#   'альфа будущее blog',
#   'otkryli laboratoriyu v',
#   'reu im g',
#   'v plehanova'],
#  ['дневник',
#   'лето прошло жарко',
#   'октября раскачали санктпетербург',
#   'собрали альфа‑движе участников',
#   'рассказываем прошло севкабель',
#   'порту лекторий собрал',
#   'топовых спикеров medium',
#   'quality подписных изданий',
#   'мфл ömankö яндекса',
#   'маркет выставка создателей',
#   'локальные питерские бренды',
#   'креаторов задать вопросы',
#   'спикерам предпринимателям open',
#   'talk узнали добиваться',
#   'успеха создавать чтото',
#   'уникальное hrзоне альфа‑банка',
#   'проводили консультации нетворкали',
#   'давали карьерные советы',
#   'сделать классное фото',
#   'резюме поэтому рядом',
#   'ребята триначетыре делали',
#   'улетные фотографии которые',
#   'украсят любое посмотри',
#   'насколько классно выглядят',
#   'закрывала движ группа',
#   'дня дождя словах',
#   'альбоме фото собрали',
#   'лица эмоции события',
#   'движа дальше фест',
#   'заканчивается отправимся раскачивать',
#   'новые города образование',
#   'магистратуры магистратура вшэ',
#   'магистратура мфти магистратура',
#   'рудн магистратура итмо',
#   'сетевая магистратура кампус',
#   'онлайнпрактика онлайнкурсы дпо',
#   'преподавателей дпо продуктовому',
#   'подходу кампус джуниор',
#   'альфа‑лаб alfa digital',
#   'school гранты стипендии',
#   'стипендии студентам гранты',
#   'студентам гранты преподавателям',
#   'мероприятия чемпионат сочи',
#   'фест экскурсии офисе',
#   'молодежный финтехмитап alfa',
#   'hack карьера вакансии',
#   'опыта амбассадоры менторство',
#   'стажировки партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее',
#   'blog piterskie',
#   'studenty zapomnyat',
#   'etu tusovku'],
#  ['дневник',
#   'альфа‑банк вшэ',
#   'объединяются готовить',
#   'новых лидеров',
#   'финтеха регионах',
#   'россии стыке',
#   'финансов продуктового',
#   'подхода лучших',
#   'студентов ждет',
#   'работа альфа‑банке',
#   'это мощный',
#   'шаг карьере',
#   'обучение решением',
#   'реальных кейсов',
#   'топовых экспертов',
#   'альфы программа',
#   'нацелена практические',
#   'знания которые',
#   'реально работают',
#   'рынке открывают',
#   'крутые возможности',
#   'программа охватывает',
#   'университетов алтгу',
#   'барнаул двфу',
#   'владивосток сфу',
#   'красноярск тогу',
#   'хабаровск тюмгу',
#   'тюмень улгу',
#   'ульяновск урфу',
#   'екатеринбург юфу',
#   'ростовнадону окончании',
#   'программы выпускники',
#   'получат диплома',
#   'ниу вшэ',
#   'вузапартнера старт',
#   'программы году',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее blog',
#   'setevaya magistratura',
#   'po fintehu'],
#  ['молодежный финтехмитап',
#   'молодежный финтехмитап',
#   'прием заявок',
#   'завершен кого',
#   'офис альфа‑банка',
#   'москва маши',
#   'порываевой стр',
#   'гпрограмма пользуясь',
#   'сайтом соглашаешься',
#   'используем cookies',
#   'молодежный финтехмитап',
#   'прием заявок',
#   'завершен кого',
#   'офис альфа‑банка',
#   'москва маши',
#   'порываевой стр',
#   'гпрограмма главный',
#   'критерий отбора',
#   'заинтересованность хотим',
#   'увидеть митапе',
#   'студентов готовых',
#   'создавать будущее',
#   'финансовых технологий',
#   'страны митап',
#   'учишься очно',
#   'российском вузе',
#   'имеешь опыт',
#   'кейсчемпионатах хакатонах',
#   'работал области',
#   'финтеха интересуешься',
#   'инновациями спикеры',
#   'андрей хохлов',
#   'лидер цифровым',
#   'инновациям анна',
#   'малахова cpo',
#   'мобильного приложения',
#   'физических лиц',
#   'станислав милых',
#   'лидер диалоговым',
#   'системам секрет',
#   'скоро опубликуем',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее cbrform'],
#  ['бесплатные онлайнкурсы альфа‑банка',
#   'стажировки образование магистратура',
#   'магистратура вшэ магистратура',
#   'мфти магистратура рудн',
#   'магистратура итмо сетевая',
#   'магистратура кампус дпо',
#   'преподавателей дпо продуктовому',
#   'подходу онлайнпрактика онлайнкурсы',
#   'гранты стипендии гранты',
#   'студентам стипендии студентам',
#   'гранты преподавателям мероприятия',
#   'фест экскурсии офисе',
#   'чемпионат сочи карьера',
#   'вакансии опыта амбассадоры',
#   'менторство каталог',
#   'курсов час',
#   'альфа будущее courses'],
#  ['онлайнкурс искусственный',
#   'интеллект финтехе',
#   'курсе сегодня',
#   'искусственный интеллект',
#   'активно используют',
#   'решения бизнесзадач',
#   'курсе узнаете',
#   'принципах работы',
#   'основных этапов',
#   'функций построения',
#   'моделей внедрения',
#   'нейросетей эксперты',
#   'альфа‑банка дополнят',
#   'теорию практическими',
#   'кейсами кого',
#   'студенты длительность',
#   'часов навыки',
#   'искусственный интеллект',
#   'цифровой бизнес',
#   'курс интересно',
#   'разобраться принципах',
#   'работы искусственным',
#   'интеллектом хотите',
#   'узнать используем',
#   'нейросети разработке',
#   'продуктов банка',
#   'планируете работать',
#   'сфере хотите',
#   'погрузиться техническую',
#   'часть программа',
#   'курса базовая',
#   'часть знакомство',
#   'искусственный интеллект',
#   'естественный интеллект',
#   'история развития',
#   'искусственного интеллекта',
#   'основные типы',
#   'задач тест',
#   'модулю базовая',
#   'часть альфа‑банке',
#   'задачи альфа‑банке',
#   'альфа‑банке бизнеса',
#   'пользователей сталкиваемся',
#   'повседневной жизни',
#   'базовая часть',
#   'применение практике',
#   'искусственный интеллект',
#   'работает капотом',
#   'кита успешного',
#   'внедрения будущее',
#   'работать тест',
#   'модулю продвинутая',
#   'часть применение',
#   'классических алгоритмов',
#   'машинного обучения',
#   'финтехе базовые',
#   'понятия машинного',
#   'обучения основные',
#   'этапы жизненного',
#   'цикла взаимодействия',
#   'клиентом модели',
#   'lookalike response',
#   'upliftмодели модели',
#   'ценообразования эластичности',
#   'модели рекомендаций',
#   'ранжирования тест',
#   'модулю продвинутая',
#   'часть nlpмодели',
#   'финтехе nlpмодели',
#   'data science',
#   'основные принципы',
#   'разработки использования',
#   'кластеризация данных',
#   'разметка данных',
#   'моделирование практике',
#   'кейсы чатбот',
#   'голосовой бот',
#   'кейс ассистент',
#   'оператора тест',
#   'модулю продвинутая',
#   'часть применение',
#   'нейросетей финтехе',
#   'основные типы',
#   'задач которые',
#   'решают нейросети',
#   'финтехе банковские',
#   'последовательные данные',
#   'нейросетевой подход',
#   'построению моделей',
#   'последовательных данных',
#   'задача кредитного',
#   'скоринга задачи',
#   'склонности оттока',
#   'улучшение кредитного',
#   'скоринга помощью',
#   'единой нейросетевой',
#   'модели социальный',
#   'скоринг тест',
#   'модулю продвинутая',
#   'часть внедрение',
#   'моделей тесты',
#   'сплиттестирование развертывание',
#   'решения продакшн',
#   'стать datascience',
#   'специалистом тест',
#   'модулю результаты',
#   'обучения базовая',
#   'часть погружаетесь',
#   'тему узнаете',
#   'историю создания',
#   'развития поймете',
#   'уступает вашему',
#   'интеллекту познакомитесь',
#   'основными задачами',
#   'которые решает',
#   'поймете помогает',
#   'создавать сервисы',
#   'клиентов альфа‑банка',
#   'продвинутая часть',
#   'хотите подробно',
#   'изучить узнаете',
#   'используются nlpмодели',
#   'кластеризации разметке',
#   'данных разберетесь',
#   'конкретных кейсах',
#   'нейронные сети',
#   'применяются финтехе',
#   'изучите классические',
#   'алгоритмы машинного',
#   'обучения примерах',
#   'финтеха ответы',
#   'вопросы чему',
#   'научусь курсе',
#   'узнаете устройстве',
#   'возможностях искусственного',
#   'интеллекта увидите',
#   'используют разработке',
#   'продуктов модулях',
#   'специалистов научитесь',
#   'работать моделями',
#   'машинного обучения',
#   'nlp курсом',
#   'работали экспертов',
#   'альфа‑банка заложили',
#   'программу теорию',
#   'поделились практическими',
#   'примерами уровень',
#   'сложности курс',
#   'рассчитан начальный',
#   'уровень знаний',
#   'представление теме',
#   'учиться интереснее',
#   'эксперты часто',
#   'приводят примеры',
#   'практики насколько',
#   'интенсивное обучение',
#   'курс проходить',
#   'удобное время',
#   'комфортном темпе',
#   'расписания дедлайнов',
#   'долго доступ',
#   'курсу доступ',
#   'ограничен материалам',
#   'вернуться любой',
#   'момент понадобится',
#   'что‑то вспомнить',
#   'повторить обучение',
#   'бесплатное обучение',
#   'курсе бесплатное',
#   'альфа будущее courses'],
#  ['названия',
#   'введите номер',
#   'телефона телефон',
#   'телефон продолжить',
#   'альфа будущее authorization'],
#  ['онлайнкурс финансовая грамотность',
#   'курсе курс поможет',
#   'разобраться накопить сохранить',
#   'приумножить деньги узнаете',
#   'работают вклады кредиты',
#   'акции другие инструменты',
#   'сможете составить финансовый',
#   'план защитить доходы',
#   'мошенников кого длительность',
#   'часа навыки финансовая',
#   'грамотность финансы результаты',
#   'обучения поймете работают',
#   'акции облигации другие',
#   'инструменты инвестора оцените',
#   'свое финансовое состояние',
#   'поставите цель составите',
#   'план разберетесь нюансах',
#   'вкладов накопительных счетов',
#   'кредитов будете знать',
#   'защитить накопления мошенников',
#   'курс чувствуете недостаточно',
#   'уверенно управляете своими',
#   'финансами интересны инвестиции',
#   'хотите узнать хотите',
#   'узнать устроены основные',
#   'финансовые инструменты важно',
#   'понять защищать своих',
#   'близких действий мошенников',
#   'программа курса модуль',
#   'финансовая грамотность первые',
#   'шаги такое финансовая',
#   'грамотность отношения деньгами',
#   'оценка финансового состояния',
#   'финансовый план тест',
#   'модулю модуль копим',
#   'сохраняем финансовые привычки',
#   'финансовая математика вклады',
#   'накопительные счета кредиты',
#   'финансовый план выйти',
#   'минуса финансовый план',
#   'накопить тест модулю',
#   'модуль преумножаем правила',
#   'инвестирования облигации акции',
#   'другие варианты активов',
#   'финансовый план заработать',
#   'помощью инвестиций тест',
#   'модулю модуль защищаем',
#   'виды мошеннических схем',
#   'способы защиты мошенников',
#   'защитить свои активы',
#   'неблагоприятной макроэкономической ситуации',
#   'тест модулю ответы',
#   'вопросы чему научусь',
#   'курсе будете чувствовать',
#   'увереннее финансовых вопросах',
#   'сможете поставить цель',
#   'составить план действий',
#   'использовать финансовые инструменты',
#   'повседневной жизни защитить',
#   'доходы мошеннических схем',
#   'уровень сложности курс',
#   'тех начинает интересоваться',
#   'финансовой грамотностью знания',
#   'теме сможете понять',
#   'направления дальнейшего изучения',
#   'насколько интенсивное обучение',
#   'курс проходить удобное',
#   'время комфортном темпе',
#   'расписания дедлайнов долго',
#   'доступ курсу доступ',
#   'ограничен материалам вернуться',
#   'любой момент понадобится',
#   'что‑то вспомнить повторить',
#   'обучение бесплатное обучение',
#   'курсе бесплатное',
#   'альфа будущее courses'],
#  ['названия',
#   'магистратура кампус мои',
#   'курсы удалось загрузить',
#   'попробуй снова должно',
#   'сработать попробовать',
#   'альфа будущее courses'],
#  ['онлайнкурс продуктовый менеджмент',
#   'курсе создание классного',
#   'продукта требует внимания',
#   'этапах разработки вместе',
#   'экспертами альфа‑банка пройдете',
#   'весь цикл продуктовой',
#   'разработки узнаете принципах',
#   'управления проектами разберете',
#   'примеры практики кого',
#   'длительность часа навыки',
#   'продуктовый менеджмент результаты',
#   'обучения узнаете основах',
#   'продуктового подхода ролях',
#   'команде научитесь создавать',
#   'бриф продукта проводить',
#   'исследования сможете строить',
#   'клиентский путь создавать',
#   'ценность каждом этапе',
#   'поймете тестировать продукт',
#   'измерять результаты курс',
#   'любопытно разобраться создаются',
#   'классные продукты классная',
#   'идея хотите понять',
#   'докрутить реального продукта',
#   'учитесь продуктовому менеджменту',
#   'хотите повысить насмотренность',
#   'продукт хотите понять',
#   'сделать привлекательнее программа',
#   'курса модуль создается',
#   'продукт основы продуктового',
#   'подхода продуктовая команда',
#   'бриф создание продукта',
#   'тест модулю модуль',
#   'продуктовые исследования алгоритм',
#   'проведения исследования анализ',
#   'рынка глубинные интервью',
#   'юзабилититестирование тест модулю',
#   'модуль проектирование продукта',
#   'методы управления проектом',
#   'value proposition canvas',
#   'формирование customer journey',
#   'map строим value',
#   'proposition canvas customer',
#   'journey map составление',
#   'финансовой модели abтесты',
#   'тест модулю модуль',
#   'анализ результатов запуска',
#   'типы метрик сбор',
#   'данных формирования метрик',
#   'экшнплан итогам анализа',
#   'результатов запуска тест',
#   'модулю ответы вопросы',
#   'чему научусь курсе',
#   'познакомитесь продуктовой командой',
#   'узнаете обо основных',
#   'шагах работе продуктом',
#   'брифа релиза идея',
#   'продукта полученные курсе',
#   'знания помогут реализовать',
#   'работаете продактменеджменте сможете',
#   'прокачать насмотренность уровень',
#   'сложности курс рассчитан',
#   'тех начинает работать',
#   'продуктом интересен опытным',
#   'слушателям легче разобраться',
#   'теме начинаем общих',
#   'знаний затем переходим',
#   'примерам практики насколько',
#   'интенсивное обучение курс',
#   'проходить удобное время',
#   'комфортном темпе расписания',
#   'дедлайнов долго доступ',
#   'курсу доступ ограничен',
#   'материалам вернуться любой',
#   'момент понадобится что‑то',
#   'вспомнить повторить обучение',
#   'бесплатное обучение',
#   'курсе бесплатное',
#   'альфа будущее courses'],
#  ['школаэксперимент студентов вышки',
#   'alfa digital',
#   'school школаэксперимент',
#   'студентов вышки',
#   'которые боятся',
#   'учиться прием',
#   'заявок закрыт',
#   'alfa digital',
#   'school школаэксперимент',
#   'студентов вышки',
#   'которые боятся',
#   'учиться прием',
#   'заявок закрыт',
#   'открываем возможность',
#   'попробовать разных',
#   'диджиталпрофессиях реальный',
#   'кейс вместе',
#   'командой разработаешь',
#   'диджиталпроект основе',
#   'кейса альфа‑банка',
#   'попробуешь разных',
#   'профессиях поймешь',
#   'тебе ближе',
#   'никаких скучных',
#   'лекций полученные',
#   'знания применишь',
#   'практике пройдешь',
#   'этапы развития',
#   'продукта идеи',
#   'прототипа эксперты',
#   'альфы помогут',
#   'реализации полезная',
#   'обратная связь',
#   'пути созданию',
#   'прототипа будешь',
#   'получать фидбэк',
#   'экспертов учиться',
#   'ошибках итогам',
#   'школы команд',
#   'защита проекта',
#   'смена ролей',
#   'твоя роль',
#   'постоянно меняться',
#   'например первую',
#   'неделю командой',
#   'будете исследователями',
#   'вторую неделю',
#   'станете аналитиками',
#   'третью дизайнерами',
#   'финальный результат',
#   'каждого пройденного',
#   'блока будешь',
#   'создавать артефакты',
#   'воркфлоу документацию',
#   'модели интерфейса',
#   'конце работы',
#   'проектом соберутся',
#   'общую картину',
#   'дальше отберем',
#   'самых мотивированных',
#   'студентов объединим',
#   'команд работать',
#   'реальным кейсом',
#   'альфа‑банка обучение',
#   'продлится ноября',
#   'декабря научишься',
#   'генерации идей',
#   'навыкам продуктового',
#   'дизайна проведению',
#   'исследований анализу',
#   'конкурентов основам',
#   'продуктовой аналитики',
#   'работе бизнес',
#   'требованиями созданию',
#   'тестированию прототипов',
#   'главный критерий',
#   'отбора заинтересованность',
#   'хотим увидеть',
#   'школе тех',
#   'кому важно',
#   'работать приносить',
#   'результат условия',
#   'alfa digital',
#   'school максимально',
#   'приближены реальным',
#   'поэтому школу',
#   'пройдут готов',
#   'взрослеть создавать',
#   'руководить эта',
#   'школа учишься',
#   'курсе высшей',
#   'школы экономики',
#   'работаешь результат',
#   'можешь ставить',
#   'цели достигать',
#   'эксперты курса',
#   'оксана франгулянц',
#   'алиса сторчак',
#   'это discovery',
#   'channel татьяна',
#   'григорьева анна',
#   'минакова знаем',
#   'разговора мужиком',
#   'скамейке сделать',
#   'фичу мария',
#   'фомичева фокусы',
#   'экспериментами разработки',
#   'илья андреев',
#   'гроусхакер брейнштормер',
#   'яков лысков',
#   'лидер направления',
#   'гроус хак',
#   'продакт любитель',
#   'китайского чая',
#   'георгий плищенко',
#   'лид аналитиков',
#   'физиков банке',
#   'павел макаров',
#   'дизайнерзануда елена',
#   'пяткова отвечаю',
#   'продуктовых аналитиков',
#   'которые исследуют',
#   'поведение клиентов',
#   'цифровых продуктах',
#   'банка дима',
#   'матвейчук профессионально',
#   'обманываю ожидания',
#   'елена бычкова',
#   'отвечаю платформу',
#   'цифровых каналах',
#   'кирилл викентьев',
#   'разрушитель мифов',
#   'digital секрет',
#   'скоро опубликуем',
#   'секрет скоро',
#   'опубликуем ответы',
#   'вопросы нужно',
#   'уметь участвовать',
#   'работать результат',
#   'ставить цели',
#   'никаких специальных',
#   'навыков нужно',
#   'совмещать школу',
#   'учебой главное',
#   'уделять проекту',
#   'часов неделю',
#   'время сессии',
#   'школа завершится',
#   'декабря совмещать',
#   'придется какие',
#   'навыки получу',
#   'получишь представление',
#   'нескольких диджиталпрофессиях',
#   'сразу сможешь',
#   'понять насколько',
#   'тебе подходят',
#   'поймешь принципы',
#   'создания продукта',
#   'работы команде',
#   'научишься ставить',
#   'задачи задавать',
#   'нужные вопросы',
#   'образование магистратуры',
#   'магистратура вшэ',
#   'магистратура мфти',
#   'магистратура рудн',
#   'магистратура итмо',
#   'сетевая магистратура',
#   'кампус онлайнпрактика',
#   'онлайнкурсы дпо',
#   'преподавателей дпо',
#   'продуктовому подходу',
#   'кампус джуниор',
#   'альфа‑лаб alfa',
#   'digital school',
#   'гранты стипендии',
#   'стипендии студентам',
#   'гранты студентам',
#   'гранты преподавателям',
#   'мероприятия чемпионат',
#   'сочи фест',
#   'экскурсии офисе',
#   'молодежный финтехмитап',
#   'alfa hack',
#   'карьера вакансии',
#   'опыта амбассадоры',
#   'менторство стажировки',
#   'партнерства стать',
#   'партнером поддержка',
#   'карта сайта',
#   'альфа будущее digitalschool']]

# %%
# Создание предсказаний с transformers
pipeline = TransformersPredictionPipeline(pooling_method="cls")  # или "mean"

# Базовый подход
pairs_results = pipeline.fit_predict_pairs(questions_cleaned, websites_cleaned, k=5)

# Или расширенный подход
# pairs_results = pipeline.fit_predict_pairs_advanced(
#     questions_cleaned, websites_cleaned, k=5, weights=(0.5, 0.3, 0.2)
# )

# Создание финального датафрейма
result_df = pipeline.get_top_k_dataframe(pairs_results, k=5)

# Сохранение результатов
result_df.to_csv('submit.csv', index=False)

print("Результаты сохранены!")
print(result_df.head())
# Out:
# Загрузка модели: ai-forever/ru-en-RoSBERTa
# model.safetensors:   0%|          | 0.00/1.61G [00:00<?, ?B/s]
